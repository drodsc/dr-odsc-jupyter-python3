# %% [markdown]
# ### DataRobot prediction via V1 API

# %%
import requests
import sys

DATAROBOT_KEY = '35dde409-9091-697e-31f3-a9fd3b67842e'
API_KEY = ''
USERNAME = ''

DEPLOYMENT_ID = ''
MAX_PREDICTION_FILE_SIZE_BYTES = 52428800  # 50 MB

# %%
headers = {'Content-Type': 'text/plain; charset=ISO-8859-1', 'datarobot-key': '35dde409-9091-697e-31f3-a9fd3b67842e'}

url = 'https://cfds.orm.eu.datarobot.com/predApi/v1.0/deployments/{deployment_id}/predictions'.format(
        deployment_id=DEPLOYMENT_ID)

# %%
#data = open('../../Data/10k_diabetes_ODSC_Prediction.csv', 'rb').read()
data = open('../../Data/10k_diabetes_ODSC_Prediction_Drifted.csv', 'rb').read()

# %%
predictions_response = predictions_response = requests.post(
                                                            url,
                                                            auth=(USERNAME, API_KEY),
                                                            data=data,
                                                            headers=headers,
                                                        )

# %%
predictions_response.json()
# Out:
# {'data': [{'predictionValues': [{'value': 0.645645082, 'label': 1.0},
#     {'value': 0.354354918, 'label': 0.0}],
#    'predictionThreshold': 0.2895,
#    'rowId': 0,
#    'prediction': 1.0},
#   {'predictionValues': [{'value': 0.5234864354, 'label': 1.0},
#     {'value': 0.4765135646, 'label': 0.0}],
#    'predictionThreshold': 0.2895,
#    'rowId': 1,
#    'prediction': 1.0},
#   {'predictionValues': [{'value': 0.3540852964, 'label': 1.0},
#     {'value': 0.6459147036, 'label': 0.0}],
#    'predictionThreshold': 0.2895,
#    'rowId': 2,
#    'prediction': 1.0},
#   {'predictionValues': [{'value': 0.6489505172, 'label': 1.0},
#     {'value': 0.3510494828, 'label': 0.0}],
#    'predictionThreshold': 0.2895,
#    'rowId': 3,
#    'prediction': 1.0},
#   {'predictionValues': [{'value': 0.6081386805, 'label': 1.0},
#     {'value': 0.3918613195, 'label': 0.0}],
#    'predictionThreshold': 0.2895,
#    'rowId': 4,
#    'prediction': 1.0},
# ...
